# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([[1,2,3],
                   [None,5,6],
                   [None,8,9],
                   [10,11,12]
                   ], 
                  columns=["A", "B", "C"], 
                  index=["x","y","z",'zz'])

# %%
df
# Out:
#        A   B   C
# x    1.0   2   3
# y    NaN   5   6
# z    NaN   8   9
# zz  10.0  11  12

# %%
df.head(2)
# Out:
#      A  B  C
# x  1.0  2  3
# y  NaN  5  6

# %%
df.tail(2)
# Out:
#        A   B   C
# z    NaN   8   9
# zz  10.0  11  12

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.index
# Out:
# Index(['x', 'y', 'z', 'zz'], dtype='object')

# %%
df.index.tolist()
# Out:
# ['x', 'y', 'z', 'zz']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, x to zz
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       2 non-null      float64
#  1   B       4 non-null      int64
#  2   C       4 non-null      int64
# dtypes: float64(1), int64(2)
# memory usage: 128.0+ bytes

# %%
df.describe()
# Out:
#                A          B          C
# count   2.000000   4.000000   4.000000
# mean    5.500000   6.500000   7.500000
# std     6.363961   3.872983   3.872983
# min     1.000000   2.000000   3.000000
# 25%     3.250000   4.250000   5.250000
# 50%     5.500000   6.500000   7.500000
# 75%     7.750000   8.750000   9.750000
# max    10.000000  11.000000  12.000000

# %%
df
# Out:
#        A   B   C
# x    1.0   2   3
# y    NaN   5   6
# z    NaN   8   9
# zz  10.0  11  12

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.nunique(axis=1) # per row
# Out:
# x     3
# y     2
# z     2
# zz    3
# dtype: int64

# %%
df.nunique(axis=0) # per column
# Out:
# A    2
# B    4
# C    4
# dtype: int64

# %%
df['A']
# Out:
# x      1.0
# y      NaN
# z      NaN
# zz    10.0
# Name: A, dtype: float64

# %%
df['A'].unique()
# Out:
# array([ 1., nan, 10.])

# %%
df
# Out:
#        A   B   C
# x    1.0   2   3
# y    NaN   5   6
# z    NaN   8   9
# zz  10.0  11  12

# %%
df.shape
# Out:
# (4, 3)

# %%
df.size
# Out:
# 12

# %%
coffee = pd.read_csv('coffee.csv')
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.index
# Out:
# RangeIndex(start=0, stop=14, step=1)

# %%
# results = pd.read_parquet('results.parquet')
# bios = pd.read_csv('bios.csv')
# olympics_data = pd.read_excel('olympics-data.xlsx', sheet_name="results")

# %%
coffee.sample(5)
# Out:
#          Day Coffee Type  Units Sold
# 9     Friday       Latte          35
# 7   Thursday       Latte          30
# 1     Monday       Latte          15
# 11  Saturday       Latte          35
# 3    Tuesday       Latte          20

# %%
coffee.loc[0:1, :]  # label based indexing
# Out:
#       Day Coffee Type  Units Sold
# 0  Monday    Espresso          25
# 1  Monday       Latte          15

# %%
coffee.loc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[[0, 1, 5]]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 5  Wednesday       Latte          25

# %%
coffee.loc[[0, 2], ["Day", "Units Sold"]]
# Out:
#        Day  Units Sold
# 0   Monday          25
# 2  Tuesday          30

# %%
coffee.loc[:, ["Day", "Units Sold"]]
# Out:
#           Day  Units Sold
# 0      Monday          25
# 1      Monday          15
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.iloc[:, [0, 2]] # integer based indexing
# Out:
#           Day  Units Sold
# 0      Monday          25
# 1      Monday          15
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %%
coffee.loc[0:2, :]
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30

# %%
coffee.iloc[0:2, :] # integer based indexing
# Out:
#       Day Coffee Type  Units Sold
# 0  Monday    Espresso          25
# 1  Monday       Latte          15

# %%
type(coffee.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
coffee.index
# Out:
# RangeIndex(start=0, stop=14, step=1)

# %%
coffee.index = coffee["Day"]

# %%
coffee
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35
# Wednesday  Wednesday       Latte          25
# Thursday    Thursday    Espresso          40
# Thursday    Thursday       Latte          30
# Friday        Friday    Espresso          45
# Friday        Friday       Latte          35
# Saturday    Saturday    Espresso          45
# Saturday    Saturday       Latte          35
# Sunday        Sunday    Espresso          45
# Sunday        Sunday       Latte          35

# %%
coffee.loc["Monday":"Wednesday"]
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35
# Wednesday  Wednesday       Latte          25

# %%
coffee_samples = coffee.sample(5)
coffee_samples
# Out:
#                Day Coffee Type  Units Sold
# Day
# Sunday      Sunday       Latte          35
# Tuesday    Tuesday    Espresso          30
# Thursday  Thursday    Espresso          40
# Friday      Friday    Espresso          45
# Saturday  Saturday       Latte          35

# %%
coffee_samples.loc["Sunday":"Thursday"]
# Out:
#                Day Coffee Type  Units Sold
# Day
# Sunday      Sunday       Latte          35
# Tuesday    Tuesday    Espresso          30
# Thursday  Thursday    Espresso          40

# %%
coffee = pd.read_csv('coffee.csv')
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[1:3, "Units Sold"] = 10

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.at[0, "Units Sold"] # label based indexing
# Out:
# 25

# %%
coffee.iat[0, 2]
# Out:
# 25

# %%
coffee.at[13, "Units Sold"] # label based indexing
# Out:
# 35

# %%
coffee.iat[13, 2] # label based indexing
# Out:
# 35

# %%
coffee.loc[:2, ["Day", "Units Sold"]]
# Out:
#        Day  Units Sold
# 0   Monday          25
# 1   Monday          10
# 2  Tuesday          10

# %%
coffee.iloc[:2, [0, 2]]
# Out:
#       Day  Units Sold
# 0  Monday          25
# 1  Monday          10

# %%
coffee.loc[:, ["Units Sold"]]
# Out:
#     Units Sold
# 0           25
# 1           10
# 2           10
# 3           10
# 4           35
# 5           25
# 6           40
# 7           30
# 8           45
# 9           35
# 10          45
# 11          35
# 12          45
# 13          35

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee_sorted = coffee.sort_values(by="Units Sold", ascending=False)
coffee_sorted
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10

# %%
coffee_sorted.loc[:12, ['Coffee Type']]  # :12 means "from start through label 12"
# Out:
#    Coffee Type
# 8     Espresso
# 10    Espresso
# 12    Espresso

# %%
coffee.sort_values(["Units Sold", "Coffee Type"], ascending=[False, True])
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          10
# 1      Monday       Latte          10
# 3     Tuesday       Latte          10

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
for index, row in coffee.iterrows():
    print(row)
    print('-' * 20)
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
# --------------------
# Day            Monday
# Coffee Type     Latte
# Units Sold         10
# Name: 1, dtype: object
# --------------------
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           10
# Name: 2, dtype: object
# --------------------
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          10
# Name: 3, dtype: object
# --------------------
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: 4, dtype: object
# --------------------
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: 5, dtype: object
# --------------------
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
# --------------------
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: 7, dtype: object
# ...

# %%
bios = pd.read_csv('bios.csv')

# %%
bios.columns
# Out:
# Index(['athlete_id', 'name', 'born_date', 'born_city', 'born_region',
#        'born_country', 'NOC', 'height_cm', 'weight_kg', 'died_date'],
#       dtype='object')

# %%
bios.loc[bios["height_cm"] > 215][:5]
# Out:
#       athlete_id                   name   born_date         born_city  \
# 5089        5108     Viktor Pankrashkin  1957-06-19   Moskva (Moscow)
# 5583        5606   Paulinho Villas Boas  1963-01-26         São Paulo
# 5673        5696         Gunther Behnke  1963-01-19        Leverkusen
# 5716        5739               Uwe Blab  1962-03-26  München (Munich)
# 5781        5804         Tommy Burleson  1952-02-24         Crossnore
#
#               born_region born_country                   NOC  height_cm  \
# 5089               Moskva          RUS          Soviet Union      220.0
# 5583            São Paulo          BRA                Brazil      217.0
# 5673  Nordrhein-Westfalen          GER               Germany      221.0
# 5716               Bayern          GER  Germany West Germany      218.0
# 5781       North Carolina          USA         United States      223.0
#
#       weight_kg   died_date
# 5089      112.0  1993-07-24
# 5583      106.0         NaN
# ...

# %%
bios.loc[bios["height_cm"] > 215, ["name", "height_cm"]][:5]
# Out:
#                        name  height_cm
# 5089     Viktor Pankrashkin      220.0
# 5583   Paulinho Villas Boas      217.0
# 5673         Gunther Behnke      221.0
# 5716               Uwe Blab      218.0
# 5781         Tommy Burleson      223.0

# %%
bios[["name", "height_cm", "born_country"]]
# Out:
#                          name  height_cm born_country
# 0       Jean-François Blanchy        NaN          FRA
# 1              Arnaud Boetsch      183.0          FRA
# 2                Jean Borotra      183.0          FRA
# 3             Jacques Brugnon      168.0          FRA
# 4                Albert Canet        NaN          GBR
# ...                       ...        ...          ...
# 145495      Polina Luchnikova      167.0          RUS
# 145496    Valeriya Merkusheva      168.0          RUS
# 145497        Yuliya Smirnova      163.0          RUS
# 145498         André Foussard      166.0          FRA
# 145499          Bill Phillips        NaN          AUS
#
# [145500 rows x 3 columns]

# %%
bios[bios['height_cm'] > 215][:5]
# Out:
#       athlete_id                   name   born_date         born_city  \
# 5089        5108     Viktor Pankrashkin  1957-06-19   Moskva (Moscow)
# 5583        5606   Paulinho Villas Boas  1963-01-26         São Paulo
# 5673        5696         Gunther Behnke  1963-01-19        Leverkusen
# 5716        5739               Uwe Blab  1962-03-26  München (Munich)
# 5781        5804         Tommy Burleson  1952-02-24         Crossnore
#
#               born_region born_country                   NOC  height_cm  \
# 5089               Moskva          RUS          Soviet Union      220.0
# 5583            São Paulo          BRA                Brazil      217.0
# 5673  Nordrhein-Westfalen          GER               Germany      221.0
# 5716               Bayern          GER  Germany West Germany      218.0
# 5781       North Carolina          USA         United States      223.0
#
#       weight_kg   died_date
# 5089      112.0  1993-07-24
# 5583      106.0         NaN
# ...

# %%
bios[bios['height_cm'] > 215][["name", "height_cm"]][:5]
# Out:
#                        name  height_cm
# 5089     Viktor Pankrashkin      220.0
# 5583   Paulinho Villas Boas      217.0
# 5673         Gunther Behnke      221.0
# 5716               Uwe Blab      218.0
# 5781         Tommy Burleson      223.0

# %%
bios[(bios['height_cm'] > 215) & (bios['born_country'] == 'USA')]
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %%
bios[bios['name'].str.contains("keith", case=False)][:2]
# Out:
#       athlete_id           name   born_date born_city born_region  \
# 1897        1907   Keith Hanlon  1966-09-01       NaN         NaN
# 3505        3517  Keith Wallace  1961-03-29   Preston     England
#
#      born_country            NOC  height_cm  weight_kg   died_date
# 1897          NaN        Ireland        NaN        NaN         NaN
# 3505          GBR  Great Britain      165.0       51.0  1999-12-31

# %%
bios[bios['name'].str.contains('keith | patrick', case=False)][:2]
# Out:
#       athlete_id           name   born_date born_city born_region  \
# 1897        1907   Keith Hanlon  1966-09-01       NaN         NaN
# 3505        3517  Keith Wallace  1961-03-29   Preston     England
#
#      born_country            NOC  height_cm  weight_kg   died_date
# 1897          NaN        Ireland        NaN        NaN         NaN
# 3505          GBR  Great Britain      165.0       51.0  1999-12-31

# %%
bios[bios['name'].str.contains('keith | patrick', case=False, regex=False)] 
# he pattern 'keith | patrick' is treated literally
# The | is just a regular character, not a regex operator
# Out:
# Empty DataFrame
# Columns: [athlete_id, name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []

# %%
## isin method & startswith
bios[bios['born_country'].isin(["USA", "FRA", "GBR"]) & (bios['name'].str.startswith("Keith"))][:2]
# Out:
#        athlete_id           name   born_date born_city born_region  \
# 3505         3517  Keith Wallace  1961-03-29   Preston     England
# 12053       12118   Keith Hervey  1898-11-03    Fulham     England
#
#       born_country            NOC  height_cm  weight_kg   died_date
# 3505           GBR  Great Britain      165.0       51.0  1999-12-31
# 12053          GBR  Great Britain        NaN        NaN  1973-02-22

# %%
coffee = pd.read_csv('coffee.csv')
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.columns
# Out:
# Index(['Day', 'Coffee Type', 'Units Sold'], dtype='object')

# %%
coffee['price'] = 4.99

# %%
coffee.columns
# Out:
# Index(['Day', 'Coffee Type', 'Units Sold', 'price'], dtype='object')

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price
# 0      Monday    Espresso          25   4.99
# 1      Monday       Latte          15   4.99
# 2     Tuesday    Espresso          30   4.99
# 3     Tuesday       Latte          20   4.99
# 4   Wednesday    Espresso          35   4.99
# 5   Wednesday       Latte          25   4.99
# 6    Thursday    Espresso          40   4.99
# 7    Thursday       Latte          30   4.99
# 8      Friday    Espresso          45   4.99
# 9      Friday       Latte          35   4.99
# 10   Saturday    Espresso          45   4.99
# 11   Saturday       Latte          35   4.99
# 12     Sunday    Espresso          45   4.99
# 13     Sunday       Latte          35   4.99

# %%
coffee['new_price'] = np.where(coffee['Coffee Type'] == 'Espresso', 3.99, 5.99)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new_price
# 0      Monday    Espresso          25   4.99       3.99
# 1      Monday       Latte          15   4.99       5.99
# 2     Tuesday    Espresso          30   4.99       3.99
# 3     Tuesday       Latte          20   4.99       5.99
# 4   Wednesday    Espresso          35   4.99       3.99
# 5   Wednesday       Latte          25   4.99       5.99
# 6    Thursday    Espresso          40   4.99       3.99
# 7    Thursday       Latte          30   4.99       5.99
# 8      Friday    Espresso          45   4.99       3.99
# 9      Friday       Latte          35   4.99       5.99
# 10   Saturday    Espresso          45   4.99       3.99
# 11   Saturday       Latte          35   4.99       5.99
# 12     Sunday    Espresso          45   4.99       3.99
# 13     Sunday       Latte          35   4.99       5.99

# %%
coffee.drop(columns=['price'], inplace=True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          15       5.99
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       5.99

# %%
coffee = coffee[['new_price', 'Day', 'Coffee Type', 'Units Sold']].copy()
coffee
# Out:
#     new_price        Day Coffee Type  Units Sold
# 0        3.99     Monday    Espresso          25
# 1        5.99     Monday       Latte          15
# 2        3.99    Tuesday    Espresso          30
# 3        5.99    Tuesday       Latte          20
# 4        3.99  Wednesday    Espresso          35
# 5        5.99  Wednesday       Latte          25
# 6        3.99   Thursday    Espresso          40
# 7        5.99   Thursday       Latte          30
# 8        3.99     Friday    Espresso          45
# 9        5.99     Friday       Latte          35
# 10       3.99   Saturday    Espresso          45
# 11       5.99   Saturday       Latte          35
# 12       3.99     Sunday    Espresso          45
# 13       5.99     Sunday       Latte          35

# %%
coffee['revenue'] = coffee['Units Sold'] * coffee['new_price']
coffee
# Out:
#     new_price        Day Coffee Type  Units Sold  revenue
# 0        3.99     Monday    Espresso          25    99.75
# 1        5.99     Monday       Latte          15    89.85
# 2        3.99    Tuesday    Espresso          30   119.70
# 3        5.99    Tuesday       Latte          20   119.80
# 4        3.99  Wednesday    Espresso          35   139.65
# 5        5.99  Wednesday       Latte          25   149.75
# 6        3.99   Thursday    Espresso          40   159.60
# 7        5.99   Thursday       Latte          30   179.70
# 8        3.99     Friday    Espresso          45   179.55
# 9        5.99     Friday       Latte          35   209.65
# 10       3.99   Saturday    Espresso          45   179.55
# 11       5.99   Saturday       Latte          35   209.65
# 12       3.99     Sunday    Espresso          45   179.55
# 13       5.99     Sunday       Latte          35   209.65

# %%
coffee.rename(columns={'new_price': 'price'}, inplace=True)

# %%
coffee
# Out:
#     price        Day Coffee Type  Units Sold  revenue
# 0    3.99     Monday    Espresso          25    99.75
# 1    5.99     Monday       Latte          15    89.85
# 2    3.99    Tuesday    Espresso          30   119.70
# 3    5.99    Tuesday       Latte          20   119.80
# 4    3.99  Wednesday    Espresso          35   139.65
# 5    5.99  Wednesday       Latte          25   149.75
# 6    3.99   Thursday    Espresso          40   159.60
# 7    5.99   Thursday       Latte          30   179.70
# 8    3.99     Friday    Espresso          45   179.55
# 9    5.99     Friday       Latte          35   209.65
# 10   3.99   Saturday    Espresso          45   179.55
# 11   5.99   Saturday       Latte          35   209.65
# 12   3.99     Sunday    Espresso          45   179.55
# 13   5.99     Sunday       Latte          35   209.65

# %%
bios_new = bios.copy()

# %%
bios_new.head(2)
# Out:
#    athlete_id                   name   born_date born_city born_region  \
# 0           1  Jean-François Blanchy  1886-12-12  Bordeaux     Gironde
# 1           2         Arnaud Boetsch  1969-04-01    Meulan    Yvelines
#
#   born_country     NOC  height_cm  weight_kg   died_date
# 0          FRA  France        NaN        NaN  1960-10-02
# 1          FRA  France      183.0       76.0         NaN

# %%
bios_new['first_name'] = bios_new['name'].str.split(' ').str[0]

# %%
bios_new[:3]
# Out:
#    athlete_id                   name   born_date born_city  \
# 0           1  Jean-François Blanchy  1886-12-12  Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01    Meulan
# 2           3           Jean Borotra  1898-08-13  Biarritz
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
#
#     died_date     first_name
# 0  1960-10-02  Jean-François
# 1         NaN         Arnaud
# 2  1994-07-17           Jean

# %%
bios_new.query('first_name == "Keith"')[:2]
# Out:
#       athlete_id           name   born_date born_city born_region  \
# 1897        1907   Keith Hanlon  1966-09-01       NaN         NaN
# 3505        3517  Keith Wallace  1961-03-29   Preston     England
#
#      born_country            NOC  height_cm  weight_kg   died_date first_name
# 1897          NaN        Ireland        NaN        NaN         NaN      Keith
# 3505          GBR  Great Britain      165.0       51.0  1999-12-31      Keith

# %%
bios_new['born_datetime'] = pd.to_datetime(bios_new['born_date'])

# %%
bios_new['born_year'] = bios_new['born_datetime'].dt.year

# %%
bios_new[:2]
# Out:
#    athlete_id                   name   born_date born_city born_region  \
# 0           1  Jean-François Blanchy  1886-12-12  Bordeaux     Gironde
# 1           2         Arnaud Boetsch  1969-04-01    Meulan    Yvelines
#
#   born_country     NOC  height_cm  weight_kg   died_date     first_name  \
# 0          FRA  France        NaN        NaN  1960-10-02  Jean-François
# 1          FRA  France      183.0       76.0         NaN         Arnaud
#
#   born_datetime  born_year
# 0    1886-12-12     1886.0
# 1    1969-04-01     1969.0

# %%
bios_new[['name', 'born_year']][:2]
# Out:
#                     name  born_year
# 0  Jean-François Blanchy     1886.0
# 1         Arnaud Boetsch     1969.0

# %%
def categorize_athlete(x):
    if x < 165:
        return 'Short'
    elif x < 185:
        return 'Average'
    else:
        return 'Tall'

# %%
bios['height_category'] = bios['height_cm'].apply(categorize_athlete)

# %%
# bios['height_category'] = bios['height_cm'].apply(lambda x: 'Short' if x < 165 else ('Average' if x < 185 else 'Tall'))

# %%
bios[:5]
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category
# 0  1960-10-02            Tall
# 1         NaN         Average
# 2  1994-07-17         Average
# 3  1978-03-20         Average
# 4  1930-07-25            Tall

# %%
def categorize_athlete(row):
    if row['height_cm'] < 175 and row['weight_kg'] < 70:
        return 'Lightweight'
    elif row['height_cm'] < 185 or row['weight_kg'] <= 80:
        return 'Middleweight'
    else:
        return 'Heavyweight'
    
bios['Category'] = bios.apply(categorize_athlete, axis=1)

# %%
bios.head(2)
# Out:
#    athlete_id                   name   born_date born_city born_region  \
# 0           1  Jean-François Blanchy  1886-12-12  Bordeaux     Gironde
# 1           2         Arnaud Boetsch  1969-04-01    Meulan    Yvelines
#
#   born_country     NOC  height_cm  weight_kg   died_date height_category  \
# 0          FRA  France        NaN        NaN  1960-10-02            Tall
# 1          FRA  France      183.0       76.0         NaN         Average
#
#        Category
# 0   Heavyweight
# 1  Middleweight

# %%
nocs = pd.read_csv('noc_regions.csv')
nocs
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
                   'value': [1, 2, 3, 5]})
df1
# Out:
#   lkey  value
# 0  foo      1
# 1  bar      2
# 2  baz      3
# 3  foo      5

# %%
df2 = pd.DataFrame({'rkey': ['fol', 'bar', 'baz', 'fol'],
                   'value': [5, 6, 7, 8]})
df2
# Out:
#   rkey  value
# 0  fol      5
# 1  bar      6
# 2  baz      7
# 3  fol      8

# %%
pd.merge(df1, df2, how='left',  left_on='lkey', right_on='rkey')
# Out:
#   lkey  value_x rkey  value_y
# 0  foo        1  NaN      NaN
# 1  bar        2  bar      6.0
# 2  baz        3  baz      7.0
# 3  foo        5  NaN      NaN

# %%
pd.merge(df1, df2, how='inner', right_on='rkey', left_on='lkey')
# Out:
#   lkey  value_x rkey  value_y
# 0  bar        2  bar        6
# 1  baz        3  baz        7

# %%
bios_new = pd.merge(bios, nocs, how='left', left_on='born_country', right_on='NOC')
bios_new.head(2)
# Out:
#    athlete_id                   name   born_date born_city born_region  \
# 0           1  Jean-François Blanchy  1886-12-12  Bordeaux     Gironde
# 1           2         Arnaud Boetsch  1969-04-01    Meulan    Yvelines
#
#   born_country   NOC_x  height_cm  weight_kg   died_date height_category  \
# 0          FRA  France        NaN        NaN  1960-10-02            Tall
# 1          FRA  France      183.0       76.0         NaN         Average
#
#        Category NOC_y  region notes
# 0   Heavyweight   FRA  France   NaN
# 1  Middleweight   FRA  France   NaN

# %%
bios.columns
# Out:
# Index(['athlete_id', 'name', 'born_date', 'born_city', 'born_region',
#        'born_country', 'NOC', 'height_cm', 'weight_kg', 'died_date',
#        'height_category', 'Category'],
#       dtype='object')

# %%
nocs.columns
# Out:
# Index(['NOC', 'region', 'notes'], dtype='object')

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country      NOC_x  height_cm  weight_kg  \
# ...

# %%
bios_new['NOC_y'].isna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 145495    False
# 145496    False
# 145497    False
# 145498    False
# 145499    False
# Name: NOC_y, Length: 145500, dtype: bool

# %%
bios_new.rename(columns={'region': 'born_country_full'}, inplace=True)

# %%
usa = bios[bios['born_country'] == 'USA'].copy()
gbr = bios[bios['born_country'] == 'GBR'].copy()

# %%
usa.head(2)
# Out:
#      athlete_id              name   born_date    born_city born_region  \
# 54           55     Monique Javer  1967-07-22   Burlingame  California
# 960         964  Xóchitl Escobedo  1968-09-17  West Covina  California
#
#     born_country            NOC  height_cm  weight_kg died_date  \
# 54           USA  Great Britain      177.0       64.0       NaN
# 960          USA         Mexico      170.0       60.0       NaN
#
#     height_category      Category
# 54          Average  Middleweight
# 960         Average   Lightweight

# %%
gbr.head(2)
# Out:
#     athlete_id             name   born_date   born_city born_region  \
# 4            5     Albert Canet  1878-04-17  Wandsworth     England
# 37          38  Helen Aitchison  1881-12-06  Sunderland     England
#
#    born_country            NOC  height_cm  weight_kg   died_date  \
# 4           GBR         France        NaN        NaN  1930-07-25
# 37          GBR  Great Britain        NaN        NaN  1947-05-26
#
#    height_category     Category
# 4             Tall  Heavyweight
# 37            Tall  Heavyweight

# %%
new_df = pd.concat([usa, gbr])

# %%
new_df.head()
# Out:
#       athlete_id               name   born_date         born_city born_region  \
# 54            55      Monique Javer  1967-07-22        Burlingame  California
# 960          964   Xóchitl Escobedo  1968-09-17       West Covina  California
# 961          965  Angélica Gavaldón  1973-10-03         El Centro  California
# 1231        1238     Bert Schneider  1897-07-01         Cleveland        Ohio
# 1345        1352         Laura Berg  1975-01-06  Santa Fe Springs  California
#
#      born_country            NOC  height_cm  weight_kg   died_date  \
# 54            USA  Great Britain      177.0       64.0         NaN
# 960           USA         Mexico      170.0       60.0         NaN
# 961           USA         Mexico      160.0       54.0         NaN
# 1231          USA         Canada        NaN        NaN  1986-02-20
# 1345          USA  United States      168.0       61.0         NaN
#
#      height_category      Category
# 54           Average  Middleweight
# ...

# %%
new_df.tail()
# Out:
#         athlete_id                name   born_date     born_city born_region  \
# 144811      148512  Benjamin Alexander  1983-05-08        London     England
# 144815      148517       Ashley Watson  1993-10-28  Peterborough     England
# 145005      148716     Peder Kongshaug  2001-08-13     Wimbledon     England
# 145319      149041          Axel Brown  1992-04-02     Harrogate     England
# 145388      149111      Jean-Luc Baker  1993-10-07       Burnley     England
#
#        born_country                  NOC  height_cm  weight_kg died_date  \
# 144811          GBR              Jamaica        NaN        NaN       NaN
# 144815          GBR              Jamaica        NaN        NaN       NaN
# 145005          GBR               Norway      184.0       86.0       NaN
# 145319          GBR  Trinidad and Tobago        NaN        NaN       NaN
# 145388          GBR        United States        NaN        NaN       NaN
#
#        height_category      Category
# ...

# %%
coffee.loc[[2, 3], 'Units Sold'] = np.nan

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso        25.0
# 1      Monday       Latte        15.0
# 2     Tuesday    Espresso         NaN
# 3     Tuesday       Latte         NaN
# 4   Wednesday    Espresso        35.0
# 5   Wednesday       Latte        25.0
# 6    Thursday    Espresso        40.0
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
coffee['Units Sold'].mean()
# Out:
# 34.166666666666664

# %%
coffee['Units Sold'].fillna(coffee['Units Sold'].mean())
# Out:
# 0     25.000000
# 1     15.000000
# 2     34.166667
# 3     34.166667
# 4     35.000000
# 5     25.000000
# 6     40.000000
# 7     30.000000
# 8     45.000000
# 9     35.000000
# 10    45.000000
# 11    35.000000
# 12    45.000000
# 13    35.000000
# Name: Units Sold, dtype: float64

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso        25.0
# 1      Monday       Latte        15.0
# 2     Tuesday    Espresso         NaN
# 3     Tuesday       Latte         NaN
# 4   Wednesday    Espresso        35.0
# 5   Wednesday       Latte        25.0
# 6    Thursday    Espresso        40.0
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
coffee['Units Sold'].interpolate()  
# Linear interpolation by default: draws a straight line between known values
# Calculates intermediate values based on position
# Only fills gaps between known values (doesn't fill leading/trailing NaNs)
# Out:
# 0     25.000000
# 1     15.000000
# 2     21.666667
# 3     28.333333
# 4     35.000000
# 5     25.000000
# 6     40.000000
# 7     30.000000
# 8     45.000000
# 9     35.000000
# 10    45.000000
# 11    35.000000
# 12    45.000000
# 13    35.000000
# Name: Units Sold, dtype: float64

# %%
coffee.loc[[2, 3], 'Units Sold'] = np.nan
coffee.dropna(subset=['Units Sold'], axis=0)   
# axis=0 (or axis='index') = operate along rows (vertical)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso        25.0
# 1      Monday       Latte        15.0
# 4   Wednesday    Espresso        35.0
# 5   Wednesday       Latte        25.0
# 6    Thursday    Espresso        40.0
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
coffee[coffee['Units Sold'].notna()]
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso        25.0
# 1      Monday       Latte        15.0
# 4   Wednesday    Espresso        35.0
# 5   Wednesday       Latte        25.0
# 6    Thursday    Espresso        40.0
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso        25.0
# 1      Monday       Latte        15.0
# 2     Tuesday    Espresso         NaN
# 3     Tuesday       Latte         NaN
# 4   Wednesday    Espresso        35.0
# 5   Wednesday       Latte        25.0
# 6    Thursday    Espresso        40.0
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
bios.head(2)
# Out:
#    athlete_id                   name   born_date born_city born_region  \
# 0           1  Jean-François Blanchy  1886-12-12  Bordeaux     Gironde
# 1           2         Arnaud Boetsch  1969-04-01    Meulan    Yvelines
#
#   born_country     NOC  height_cm  weight_kg   died_date height_category  \
# 0          FRA  France        NaN        NaN  1960-10-02            Tall
# 1          FRA  France      183.0       76.0         NaN         Average
#
#        Category
# 0   Heavyweight
# 1  Middleweight

# %%
bios['born_city'].value_counts()
# Out:
# born_city
# Budapest           1378
# Moskva (Moscow)     883
# Oslo                708
# Stockholm           629
# Praha (Prague)      600
#                    ...
# Bodrogkisfalud        1
# Ternberg              1
# Klaus                 1
# Plaški                1
# Dulwich Hill          1
# Name: count, Length: 22368, dtype: int64

# %%
bios[bios['born_country'] == 'USA']['born_region'].value_counts().head(5)
# Out:
# born_region
# California       1634
# New York          990
# Illinois          585
# Pennsylvania      530
# Massachusetts     530
# Name: count, dtype: int64

# %%
bios[bios['born_country'] == 'USA']['born_region'].value_counts().tail(5)
# Out:
# born_region
# South Dakota     27
# West Virginia    24
# Delaware         22
# North Dakota     16
# Wyoming          14
# Name: count, dtype: int64

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso        25.0
# 1      Monday       Latte        15.0
# 2     Tuesday    Espresso         NaN
# 3     Tuesday       Latte         NaN
# 4   Wednesday    Espresso        35.0
# 5   Wednesday       Latte        25.0
# 6    Thursday    Espresso        40.0
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].sum()
# Out:
# Coffee Type
# Espresso    235.0
# Latte       175.0
# Name: Units Sold, dtype: float64

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].sum().index
# Out:
# Index(['Espresso', 'Latte'], dtype='object', name='Coffee Type')

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].sum().reset_index()
# Out:
#   Coffee Type  Units Sold
# 0    Espresso       235.0
# 1       Latte       175.0

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].sum().reset_index(name='total_units_sold')
# Out:
#   Coffee Type  total_units_sold
# 0    Espresso             235.0
# 1       Latte             175.0

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].mean()
# Out:
# Coffee Type
# Espresso    39.166667
# Latte       29.166667
# Name: Units Sold, dtype: float64

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso        25.0
# 1      Monday       Latte        15.0
# 2     Tuesday    Espresso         NaN
# 3     Tuesday       Latte         NaN
# 4   Wednesday    Espresso        35.0
# 5   Wednesday       Latte        25.0
# 6    Thursday    Espresso        40.0
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
coffee.groupby(['Coffee Type', 'Day']).agg({'Units Sold': 'sum'})
# Out:
#                        Units Sold
# Coffee Type Day
# Espresso    Friday           45.0
#             Monday           25.0
#             Saturday         45.0
#             Sunday           45.0
#             Thursday         40.0
#             Tuesday           0.0
#             Wednesday        35.0
# Latte       Friday           35.0
#             Monday           15.0
#             Saturday         35.0
#             Sunday           35.0
#             Thursday         30.0
#             Tuesday           0.0
#             Wednesday        25.0

# %%
coffee.groupby(['Coffee Type', 'Day']).agg({'Units Sold': 'sum', 'price': 'mean'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 coffee.groupby(['Coffee Type', 'Day']).agg({'Units Sold': 'sum', 'price': 'mean'})
#
# File c:\Users\qslia\anaconda3\envs\detectron2\Lib\site-packages\pandas\core\groupby\generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File c:\Users\qslia\anaconda3\envs\detectron2\Lib\site-packages\pandas\core\apply.py:190, in Apply.agg(self)
#     187     return self.apply_str()
#     189 if is_dict_like(func):
# --> 190     return self.agg_dict_like()
# ...

# %% [markdown]
# #### Using datetime with Groupby

# %%
bios['born_date'] = pd.to_datetime(bios['born_date'])

bios['month_born'] = bios['born_date'].dt.month

bios['year_born'] = bios['born_date'].dt.year

bios.groupby([bios['year_born'], bios['month_born']])['name'].count().reset_index().sort_values('name', ascending=False)

# %% [markdown]
# ## Case Excercise

# %%
import pandas as pd
bios = pd.read_csv('bios.csv')

# %%
bios.info()

# %% [markdown]
# ### **Task 1:** We'll filter a DataFrame to find rows where athletes were either born in New Hampshire or San Francisco. This helps in narrowing down data based on specific criteria.

# %% [markdown]
# ### **Task 2:** Filter the bios DataFrame to include only athletes born in either 'New York' or 'Los Angeles'. Display the first 5 rows of the filtered DataFrame.

# %% [markdown]
# ### **Task 3:** Create a dataframe with code:

# %%
import pandas as pd


data = {
    'Date': ['2024-05-01', '2024-05-01', '2024-05-01', '2024-05-02', '2024-05-02', '2024-05-03', '2024-05-03', '2024-05-03'],
    'Item': ['Apple', 'Banana', 'Orange', 'Apple', 'Banana', 'Orange', 'Apple', 'Orange'],
    'Units Sold': [30, 21, 15, 40, 34, 20, 45, 25],
    'Price Per Unit': [1.0, 0.5, 0.75, 1.0, 0.5, 0.75, 1.0, 0.75],
    'Salesperson': ['John', 'John', 'John', 'Alice', 'Alice', 'John', 'Alice', 'John']
}

df = pd.DataFrame(data)


df

# %% [markdown]
# Add a new column to the DataFrame called Total Sales, which is calculated as Units Sold multiplied by Price Per Unit. Display the updated DataFrame.

# %% [markdown]
# ### **Task 4:** Given the created dataframe `data_existing` and  `data_new`. Merge this DataFrame with the df_existing DataFrame on ID and name it as `df_merged`. Sort `df_merged`  by Age in ascending order and display it.

# %%
import pandas as pd

data_existing = {
    'ID': [1, 2, 3, 4, 5],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, 35, 40, 45]
}

df_existing = pd.DataFrame(data_existing)

data_new = {
    'ID': [3, 4, 5, 6, 7],
    'Score': [88, 92, 85, 90, 95]
}

df_new = pd.DataFrame(data_new)

# %% [markdown]
# ### **Task 5:** Given Task 4, group the `df_merged` DataFrame by Name and calculate both the sum and average of Score. Display the resulting DataFrame.
